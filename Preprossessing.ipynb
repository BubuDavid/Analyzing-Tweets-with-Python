# %% [markdown]
# # In the notebook _Learning Twitter API_, we download 100 tweets from 100 people (Approx because some private users). Here we are going to preprocess the data

# %%
import os
import pandas as pd
from nltk.tokenize import TweetTokenizer
import nltk
import random
import string

# %%
# Collecting all paths
folderpath = "./tweets"
filepaths  = [os.path.join(folderpath, name) for name in os.listdir(folderpath)]

# %%
tweets = {}
# Looping through the files and extracting their tweets
for path in filepaths:
    username = path.split('/')[2][:-4]
    try:
        # Grabbing just the tweets
        tweets[username] = list(pd.read_csv(path, sep=',', engine='python', names=[0,1,2])[2])
    #print(username)
    except:
        print(f'This user is empty {username}')

# %%
tokens = {}
# Tokenizing with nltk
tt = TweetTokenizer()
for username in tweets:
    tokens[username] = []
    for tweet in tweets[username]:
        tokenized_tweet = tt.tokenize(tweet.lower())
        tokens[username].append(tokenized_tweet)

# %%
# Downloading the useless words in spanish
nltk.download("stopwords", quiet=True)
sw = nltk.corpus.stopwords.words("spanish")
sw += nltk.corpus.stopwords.words("english")

# %%
# We are going to clean punctuation sings too, i'm adding spanish ones
punc = string.punctuation + '–¿¡”“'
punc
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~–¿¡”“'

# %%
# Adding a function that tells me if a string is a number
def is_number(string):
    try:
        float(string)
        return True
    except:
        return False

# %%
# Cleaning this useless words
filtered_tweets = {}
for username in tweets:
    filtered_tweets[username] = []
    for index, tweet in enumerate(tokens[username]):
        filtered_tweet = [word for word in tokens[username][index] if word not in sw and not is_number(word)]
        no_punc = [i for i in  filtered_tweet if i not in punc]
        filtered_tweets[username].append(list(filter(None, no_punc)))

# %%
# Just to compare all the tweets and the process with a random user
random_username = random.choice(list(tweets.keys()))
random_tweet = random.randint(0,4)
print(random_username, random_number)

print(tweets[random_username][random_number])
print()
print(tokens[random_username][random_number])
print()
print(filtered_tweets[random_username][random_number])
# Out:
# leon_orale 2
# #sinmierdoaléxito Te compartimos la historia de Mafer egresada de la generación #17.
# "Mi experiencia en órale fue increíble y la sigue siendo aprendí bastantes cosas, al conocer mis miedos, mis talentos ocultos y además a crecer tanto en mi persona como en mi campo laboral. https://t.co/50AzGpIbrZ
#
# ['#sinmierdoaléxito', 'te', 'compartimos', 'la', 'historia', 'de', 'mafer', 'egresada', 'de', 'la', 'generación', '#17', '.', '"', 'mi', 'experiencia', 'en', 'órale', 'fue', 'increíble', 'y', 'la', 'sigue', 'siendo', 'aprendí', 'bastantes', 'cosas', ',', 'al', 'conocer', 'mis', 'miedos', ',', 'mis', 'talentos', 'ocultos', 'y', 'además', 'a', 'crecer', 'tanto', 'en', 'mi', 'persona', 'como', 'en', 'mi', 'campo', 'laboral', '.', 'https://t.co/50azgpibrz']
#
# ['#sinmierdoaléxito', 'compartimos', 'historia', 'mafer', 'egresada', 'generación', '#17', 'experiencia', 'órale', 'increíble', 'sigue', 'siendo', 'aprendí', 'bastantes', 'cosas', 'conocer', 'miedos', 'talentos', 'ocultos', 'además', 'crecer', 'persona', 'campo', 'laboral', 'https://t.co/50azgpibrz']

# %% [markdown]
# ## La última lista que se ve en la celda de arriba, es la lista final que usaremos para obtener de qué se trata el tweet, notese que están oganizados por usuario y por número de tweet c:, la lista se llama "filtered_tweets", y se supone que ese es todo el preprocesamiento que se necesita para aplicar lo que queremos C:

# %%
# Let's create a super simple model
# We are going to create a list of words and classify the tweets with this.
important_words = ['zoológico', 'zoologico', 'zoo', 'museo', 'programación', 'programacion', 'lectura', 'leer', 
                    'leyendo', 'libro', 'leí', 'lei', 'beca', 'becar', 'café', 'cafe', 'canción', 'cantar', 'cancion',
                    'películas', 'pelicula', 'película', 'peliculas', 'series', 'serie', 'música', 'danza', 'musica', 'postres'
                  ]

# %%
# Defining a simple way to detect a word in a filtered tweet.
def is_here(words, tweet):
    detected_words = []
    for word in words:
        if word in tweet:
            detected_words.append(word)
    return detected_words

# %%
important_tweets = {}
for important_word in important_words:
    important_tweets[important_word] = []
for username in tweets:
    for index, tweet in enumerate(tweets[username]):
        detected_words = is_here(important_words, tokens[username][index])
        for detected_word in detected_words:
            important_tweets[detected_word].append(tweet + f'    by: {username}')

# %%
for key, tweets in important_tweets.items():
    if tweets:
        print(key.capitalize())
        for tweet in tweets:
            print(f'*{tweet}')
            print('------------------')
        print()
        print('____________________________________________')
# Out:
# Zoológico
# *Un entrego mas de Diseños Green Day para el zoológico de León, Gto https://t.co/VvAnKm1ppI    by: DayDisenos
# ------------------
#
# ____________________________________________
# Museo
# *Colección del Museo de Arqueología del AHML.
# Olla antropomorfa encontrada en San Miguel; figura femenina en posición de hinojos, tiene restos de pintura roja. Se expone en el AHML y en https://t.co/N3c98k4CKZ podrás conocer más de estos testimonios prehispánicos de la región. https://t.co/97RWlewl5R    by: ahmleon
# ------------------
# *RT @IECGuanajuato: El experimentado artista mexicano Benjamín Romero Duarte es el próximo huésped del Museo Casa Diego Rivera. No te pierda…    by: EzraVldk
# ------------------
# *RT @CulturaColectiv: Si el #DíaDeMuertos es tu fiesta nacional favorita, entonces este museo te va a encantar 💀 https://t.co/ySxFyFWzdC    by: Fercalejandri
# ------------------
#
# ____________________________________________
# Programación
# *RT @FIACmx: ¡La IV Muestra de Danza Contemporánea está lista para recibirte!💃
#
# Aquí la programación que presentará en formato presencial y…    by: algonald
# ------------------
# *Toda la noche ha estado espectacular la programación @los40mx, @LuceroGama
# Hasta están metiendo remixes muy chidos, buena ahí :') https://t.co/sftNfD8YHe    by: Los40LeonFans
# ------------------
# *Qué herramientas para aprender programación y electrónica son vuestras preferidas?    by: scratch_school
# ------------------
# *#AlertaProgramadores Sigue desarrollando tus habilidades de programación...
#
# ¡GÁNATE una beca del 100% para el programa FUTURE DEVELOPERS (https://t.co/du4eL5wYmv) !
#
# ¡Lo ÚNICO que tienes que hacer es COMENTAR esta foto en nuestro Facebook... https://t.co/KYq63ZBS6T
#
# ¡Corre! https://t.co/KzgoOEmclS    by: SoyMentefactura
# ------------------
#
# ____________________________________________
# Lectura
# *Presento parte de mis investigaciones en diferentes formatos, como artículos para su lectura en nuestra página de internet, videos en YouTube y formato de podcast en Spotify o su servicio de Podcast preferido.    by: AlanRafaelVG
# ------------------
# *RT @MiguelCarbonell: Urge elevar el nivel de lectura en el país, sobre todo a edades tempranas. Por favor regalen libros en este fin de año.    by: BorisSlp
# ------------------
#
# ____________________________________________
# Leer
# *Me puse a llorar, tomar café, escuchar música clásica y leer poesía.
#
# (Nunca le digan a nadie mis hábitos tan emos)    by: brujamezcalera
# ------------------
# *@ReginaBlandon No sabes la felicidad que me da leer tu tweet y saber que aún hay gente en México que piensa de esta manera, te ganaste un corazón en tu tweet, mi follow, mi respeto y mi admiración total!    by: cristian_a369
# ------------------
# *RT @SinEmbargoMX: De Juan Villoro a Max Arriaga: Leer y ser feliz en un mundo donde él está son actos de disidencia https://t.co/gJMloFfcAq…    by: curillas
# ------------------
# *RT @ItzCas: Cometí el error de leer la opinión de algunos sobre las calles de Tepito atiborradas de gente y qué asco el horror de comentari…    by: GetsemanyGH
# ------------------
# *@coquelicot_calm siiii, wee, por eso voy a leer el libro jaja. bueno y porque hizo casting un actor de cobra kai jaja.    by: irving_augusto
# ------------------
# *@doctormacias Leer esto me llena de desesperanza    by: LaWicha2
# ------------------
# *@ZazilCarreras @metik Que bonito leer esto 💜    by: pan_bonito
# ------------------
# *@mpio_Leones @Contayors Naaaa pues así no oiga, yo casi no tuiteo, soy más se leer los tweets. 🤷🏻‍♀️    by: Princesa_Gorda
# ------------------
# *RT @organicplugmx: Nuestro redactor @EdiSong_ trae para ustedes 4 proyectos musicales de #Guanajuato. ¡Corre a leer!
#
# #OrganicPlugMx
#
# http…    by: txicologiaradio
# ------------------
#
# ____________________________________________
# Libro
# *¿Qué pelí veras este fin de semana?
# Te recomendamos una llevada #DeLosLibrosAlCine:📽️
#
# “Por trece razones” película basada en el libro del mismo título del escritor estadounidense, Jay Asher.
# #DeLaSalleLee📚 #YoMeQuedoEnCasaLeyendo😷 https://t.co/GvAAZ2LItN    by: BiblioDeLaSalle
# ------------------
# *#EXPOESIA | Atención a la presentación del libro “Cuadernos de letras”, con las obras ganadoras de la modalidad de literatura del #creacionjovensoria
# 📅 8 de agosto
# ⏱ 13.45 h
# 📍 La Dehesa
# @Ayto_Soria https://t.co/S5CNMaDpt6    by: cjuventudsoria
# ------------------
# *Me encanto todo el libro!!
# Y me cambio la perspectiva del amor🥰
# #elamorsolollegatresveces
# #youonlyfallinlovethreetimes
# @WordsofKateRose https://t.co/kcVsEHo9Sg    by: estefanienaye
# ------------------
# *@coquelicot_calm siiii, wee, por eso voy a leer el libro jaja. bueno y porque hizo casting un actor de cobra kai jaja.    by: irving_augusto
# ------------------
# *@duran_moctezuma qué libro es chikis?    by: irving_augusto
# ------------------
# *RT @arturoelias: Feliz porque hoy salió la pre venta de mi libro #ElNegociador
# Cómpralo YA aquí y te lo entregan a tu casa el 25 que sa…    by: omarcilloom
# ------------------
# *RT @AleGutierrez_mx: En 2026, León cumple 450 años de su fundación, este libro reúne la visión de un grupo de ciudadanos que proponemos un…    by: VieneLoMejorMX
# ------------------
#
# ____________________________________________
# Beca
# *RT @Mafergonzalezt: Dense una vuelta a mi perfil de insta,  tenemos un concurso para ganar una beca del 100% para el programa "Future devs"…    by: hack_women
# ------------------
# *@AnimasLeticia No es un reclamo, solo alguien debe de informar que es lo que sucede en sus coordinaciones regionales y me.consta pues es a mi a quien.le.dieron eso por no haberle llegado la beca a mi hijo.    by: NormaAn47937775
# ------------------
# *@AnimasLeticia Y aun peor por el Jefe de Unidad Regional, quien ante no saber dar una respuesta clara argumenta que la falta de beca a un par de alumnos de una preparatoria sea por FALTA DE PRESUPUESTO FEDERAL    by: NormaAn47937775
# ------------------
# *@AnimasLeticia Eso es excelente, lastima que aqui en.leon, gto nos digan.en la coordinacion regional que la beca a media superior no les llega a todos por falta de presupuesto federal y que no a todos les llegara, y que se necesita que algunos alumnos se den de baja.    by: NormaAn47937775
# ------------------
# *#AlertaProgramadores Sigue desarrollando tus habilidades de programación...
#
# ¡GÁNATE una beca del 100% para el programa FUTURE DEVELOPERS (https://t.co/du4eL5wYmv) !
#
# ¡Lo ÚNICO que tienes que hacer es COMENTAR esta foto en nuestro Facebook... https://t.co/KYq63ZBS6T
#
# ¡Corre! https://t.co/KzgoOEmclS    by: SoyMentefactura
# ------------------
#
# ____________________________________________
# Becar
# *@Leon_Joven @municipio_leon Estaría padre que ustedes nos pudieran becar con unas computadoras, just a thought 🤷🏻‍♂️😁    by: Braugomezzz
# ------------------
#
# ____________________________________________
# Café
# *RT @Torres_Roman_: No tomé café hoy, solo te quería tomar a ti.    by: barbaragomez_04
# ------------------
# *Me puse a llorar, tomar café, escuchar música clásica y leer poesía.
#
# (Nunca le digan a nadie mis hábitos tan emos)    by: brujamezcalera
# ------------------
# *RT @SoyJuanCarlos24: Después? Después se enfría el café.    by: dnlyraa
# ------------------
# *@Guarromantico_ Yo se lo digo todas las mañanas. Al.prepaear mi café. 🤭😜 Creí que solo era yo el loco 🙃    by: GalvanRooben
# ------------------
# *Coraje para estar solos, valentía para estar juntos y un café caliente al despertar ...    by: JCoosio
# ------------------
# *El mejor amigo que te puede salvar del sueño... Un café ☕🙂 @StarbucksMex https://t.co/SzoFkMZADE    by: Marco_A_OC
# ------------------
# *RT @beltrandelrio: Saludos al club de los que se levantan temprano en domingo aunque no tengan razón alguna para salir de casa.
#
# ¿Café?    by: nancyeugeniagar
# ------------------
# *RT @Altaciamx: ¡Ya somos 200 MIL! 🎉🎉🎉
#
# Disfruta de un delicioso café todas las mañanas con esta hermosa cafetera @NespressoMX ☕️☕️☕️
#
# Lo ún…    by: NormaFl94523831
# ------------------
# *¡Good morning beautiful people!
# Ya es viernes 😎😉🙂 de café y mezcale    by: reneeluna
# ------------------
# *Jueves con tono romántico, entre nublado y con café.
# ¡Que hoy te disfrutes mucho!
# #graciasvidaportanto    by: reneeluna
# ------------------
#
# ____________________________________________
# Canción
# *@inakialvarez @yaparateoficial  saludos a sofi durán que tiene 12 y dice que la canción de pican pican los mosquitos no está fuerte    by: alkozerC
# ------------------
# *No me vuelvo a quedar con las ganas de cantar una canción de la Trevi a todo pulmón.    by: angelicabetel
# ------------------
# *Aquí te va una canción para ti… Disfruto - Audioiko Remix de Carla Morrison
# https://t.co/0Tn0zHIbvD    by: arely032
# ------------------
# *https://t.co/Za15IdJJ9F  que tal la canción del zote.....!!!
# Jajajaj    by: bucionorma
# ------------------
# *RT @indiehuman0: "Es una canción, no la puedes amar tanto"
#
# La canción: https://t.co/GmK0UZ3PUv    by: Caro_linaRE
# ------------------
# *Canción favorita de la semana ❤️🎧 https://t.co/2XYLnRWaDD    by: eduardo_jegn
# ------------------
# *Generalmente cuando nos gusta un chingo una canción la presumimos por su letra, pero ¿qué procede cuando no trae letra? ¿Se tararea o qué?    by: fabionoski
# ------------------
# *@Amee_QS ME SUENA A UNA CANCIÓN.  PERO A CUAL. A CUAL??? https://t.co/DU5VJGAlDC    by: JESUS51432017
# ------------------
# *RT @tigresdelnorte: Si acaso vuelves para que volvamos a estar juntos, olvidemos el pasado y escuchemos esta canción. ¡Disfruta de este mus…    by: LaRancheritaFM
# ------------------
# **Suena una canción de Santa Fe Klan*
#
# Automáticamente yo: https://t.co/LAgQB70o0h    by: LA_AR_
# ------------------
# **Ángel Quezada ft. Ed Maverick en _Paruno Music_
#
# El tercer distrito de León De Los Aldama se levanta en palmas. El festival de la canción Luis Montes 2035 culmina con éxito.*
# https://t.co/l6jFvcJkEP    by: LA_AR_
# ------------------
# *RT @MalditaSummer: Me podré bañar con agua fría pero jamás con una canción que no me guste.    by: LuSozaJ
# ------------------
# *RT @larixtinita: recordemos esta última escena de nuestra serie, ser mejor es la canción más especial 💜
# #9añosDeVioletta
# https://t.co/6htDT…    by: odette_mugo
# ------------------
# *RT @fallingtinita: la mejor canción de violetta si o si #9añosDeVioletta https://t.co/clnunHtRm5    by: odette_mugo
# ------------------
# *RT @frenchtinista: esta canción para siempre en mi corazón #9añosDeVioletta https://t.co/ARzQ6xigVK    by: odette_mugo
# ------------------
# *La nueva canción de @justinbieber 100/10 https://t.co/aWYqVznBDt    by: PiterVanderbilt
# ------------------
# *RT @marianawismann: Si alguna vez dejamos de hablar y no sabes cómo regresar, mándame una canción    by: ValadesArely
# ------------------
#
# ____________________________________________
# Cantar
# *No me vuelvo a quedar con las ganas de cantar una canción de la Trevi a todo pulmón.    by: angelicabetel
# ------------------
# *@joseheronleyva Pues trabajar amigo y cantar la tesis y tú?    by: ichbinnambo
# ------------------
# *RT @lorenagm7: Cómo coño no voy a amar a los taxistas si acabo de cantar a dueto con uno ‘Lady Laura’ de Roberto Carlos. ¿Esto te lo hace u…    by: marioal27125763
# ------------------
#
# ____________________________________________
# Películas
# *RT @AztecaSiete: Aventura, acción y ciencia ficción, es lo que te espera este domingo en @AztecaSiete con estas increíbles películas y nues…    by: AndreaArambur13
# ------------------
# *@lopezobrador_ Así se ve en las películas de de Pixar 🐷 https://t.co/BeQy2DfZmy    by: chuckyleon1
# ------------------
# *¡El equipo crece! 💕 Hoy se une Elena Gallardo, egresada de Relaciones Internacionales en el ITAM, estudiante de Maestría en Design Studies en CENTRO. Disfruta mucho ver películas y la fotografía análoga. https://t.co/7SUqLFXmGP    by: CMinds_co
# ------------------
# *@thalmusa Tal vez me recuerden por películas . Cómo    by: dontitomartinez
# ------------------
# *También otra cosa que me caga del mundo, además de las películas de Adam Sandler, son las pinches personas que se vuelven super fan de todo lo "cool" que ven, no un fan saludable que disfruta del contenidor en la soledad, sino un fan enfermizo que quiere hacerle ver a todos ...    by: isis_daniela_
# ------------------
# *RT @carlyhb: Al carajo todas las películas de acción sobre la Casa Blanca, está imagen las supera a todas. https://t.co/TKec4U3weT    by: milagrosjgp
# ------------------
# *Para los que empiezan a acercarse al cine, es importante echarse un clavado en aquellas famosas listas de mejores películas, no te tienen que gustar todas, pero va a tener referentes.
# Comenta Edgar Apanco en #ElSalóndelaCrítica
#
# https://t.co/9Zp8gxRPNX    by: PRENSAGIFF
# ------------------
# *Si ves este tuit estás obligado a citarlo con una de tus películas favoritas. https://t.co/w5tZYjxKbl https://t.co/QoN8kCgyQD    by: SoyIsaacBanda
# ------------------
#
# ____________________________________________
# Película
# *Shrek es la mejor película ✨🤍    by: anaid_aa
# ------------------
# *¿Qué pelí veras este fin de semana?
# Te recomendamos una llevada #DeLosLibrosAlCine:📽️
#
# “Por trece razones” película basada en el libro del mismo título del escritor estadounidense, Jay Asher.
# #DeLaSalleLee📚 #YoMeQuedoEnCasaLeyendo😷 https://t.co/GvAAZ2LItN    by: BiblioDeLaSalle
# ------------------
# *RT @webcamsdemexico: De película...
# #Manzanillo está tarde.
#
# Vía: @majohdzb.
# https://t.co/1YgccSIcqI    by: cave1989
# ------------------
# *Esta parte de la película de Apocalypto tiene una profunda enseñanza https://t.co/ZHOFk0egdC    by: DaniSanchez_Lu
# ------------------
# *acabo de ver el trailer de la película de Venus y Serena.. y ahora soy más feliz :))    by: davidmontes_o
# ------------------
# *La ventaja de tener nombre de telenovela en un país anglosajón es que puedo ligar sólo con decir mi nombre completo con acento de latino en película de Eugenio Derbez.    by: LA_AR_
# ------------------
# *Las personas que escriben los jajaja... con espacios, que tienen en la cabeza? Maldad?, o solo ríen así normalmente... es que no imagino a alguien riendo así
# (Ja   Ja   Ja   Ja)
# Es como el villano de la película creyendo que se saldrá con la suya.    by: LuSozaJ
# ------------------
# *✨🎥🎬📸🎇✨
# Luz, cámara, acción!
#
# Nuestro taller de cine, para niñas, niños y adolescentes está a pocos días de comenzar.
#
# Junto con tu maestro Mayed Nazzoure aprenderás la construcción de la narrativa y la fotografía y estética general de una película.
#
# ¡No se lo pueden perder! https://t.co/xqxvFbPb7o    by: MicroteatroLeon
# ------------------
# *RT @divina_flor: Como de película la tormenta eléctrica de hace rato en #LeónGto. #lluvia #Tormentas #cielo https://t.co/wtwXFXZVfi    by: Moni43640840
# ------------------
# *@harry_rayo @angelesazulesmx @telediario @azucenau @janupi @MaguichaDoria Hola, ¿cómo se llama esa película?    by: PepeMolop
# ------------------
# *@andreacevez @LeyendasPodcast Donde viste la película? Está en alguna aplicación de streaming?    by: RenoMx2
# ------------------
# *¡De película 🎥! Tras una persecución aérea y terrestre @FSPE_Gto @AlvarCdeV @FGEGUANAJUATO lograron la captura de tres personas que presuntamente participaron en la #fuga de un #exalcalde en el estado de #Hidalgo,que usaba una 🚑
# https://t.co/VlRgt5yXNS https://t.co/Typ2No7hLX    by: SoyMRnoticias
# ------------------
# *RT @SoyNovioDeTodas: Yo después de ver una película romántica, sabiendo que nadie me va amar de esa manera. https://t.co/iMZI3JI5yM    by: tita_SalazarO
# ------------------
#
# ____________________________________________
# Series
# *Thanks for following the Lightning Talks series, it's been an amazing week! We look forward to seeing you today:
#
# 🗣️Lily Xu, Harvard University
# 💻 Protecting Forests and Endangered Species: PAWS
# 🕠5:00 pm CT.
# 🐦English/Spanish.
#
# #AIforClimate #AIforGood #ClimateAction https://t.co/iDFJMri1hB    by: CMinds_co
# ------------------
# *@DanielaMunova Tú con cada una de las series que ves    by: friliz
# ------------------
# *@WarnerChannelLA Los capítulos de estreno de sus series de Lunes a Jueves 9pm, repintanlos como lo hacían antes en lugar de la serie E.R.    by: RamonOswaldo_
# ------------------
# *RT @GQMexico: #Lucifer (Temporada 5 Parte 2) se ha convertido en los últimos años en una de las series más populares de Netflix. El mismo d…    by: virianlov
# ------------------
#
# ____________________________________________
# Serie
# *RT @CulturaColectiv: Las papas gajo son un clásico botanero, aprende a hacerlas en casa y disfrútalas viendo tu serie favorita 🤩 #CCÑAS htt…    by: AlitaGodin
# ------------------
# *RT @VILLALVAZO13: De la serie #HijosDeLaChingada, les presento: #SaqueosUnaPandemia. https://t.co/G2Nb4c6x7A    by: bucionorma
# ------------------
# *Únete a la serie de mesas de diálogo de la @GIZMexico, la @SRE_Mx y nuestro #EonResilienceLab para sumar a la conversación en el marco de la Hoja de Ruta del Secretario General de la @ONU_es 🌐 para la #cooperaciondigital
#
# Conoce los temas y regístrate: https://t.co/UT829lbGVS 🤩 https://t.co/IeB1y3FiW7    by: CMinds_co
# ------------------
# *#Viral | 📸🌐Esta serie de fotos enTwitter se hizo viral al mostrar una "historia" sobre las consecuencias de ignorar las indicaciones para prevenir el contagio de #Covid.
#
# ➡️¿Qué piensas sobre los eventos familiares ahora que el semáforo está en naranja? 🚦😷 https://t.co/tdtxbk5YK5    by: ElMedioLeon
# ------------------
# *⛪️ "La cultura y la tradición nunca son ideológicas, siempre son instintivas".  📸
# Camilo José Cela.
#
# Serie: Mi barrio, mi casa.
# Coecillo.
# León, Gto.
#
# #gea #gealcance #foto #ciudad #barrio #BuenDia #buenosdias #FelizDia https://t.co/qjcEx2USHK    by: gealcance
# ------------------
# *⛪️ Historia, tradiciones y cultura. ¿Qué sería de una ciudad sin sus barrios?
#
# Serie: Mi barrio, mi casa.
# Coecillo.
# León, Gto.
#
# #gea #gealcance #foto #ciudad #barrio #FelizJueves #BuenosDias #BuenJueves https://t.co/2nKV0oHUKb    by: gealcance
# ------------------
# *@soy_gabe https://t.co/iH7HWPHYrT 👌🏼 pones una serie mientras haces la rutina diaria y ni la sientes    by: jessybaez
# ------------------
# *Desde hace meses tengo un miedo ENORME a emocionarme por algo, evento o compromiso.
# Cumpleaños d un amigx? Día d jugar D&amp;D? Estrena una serie/disco/juego que esperaba? = EPISODIO DEPRESIVO y/o ATAQUE DE ANSIEDAD.
# Estoy harto d no poder disfrutar a las personas o cosas q amo. https://t.co/gZedOJskAs    by: jfcomascorro
# ------------------
# *Buena referencia a la escena final de el fantástico episodio 9(Cronológicamente el último de la serie). https://t.co/cMJy9GcTaL https://t.co/qgPXS0MRwm    by: Johan_andWolf
# ------------------
# *RT @nexosmexico: A continuación se muestra una serie de análisis de indicadores que aportan evidencia sobre cómo algunas de las ideas sumam…    by: LA_AR_
# ------------------
# *@PrimeVideoMX  @VivoEnLeon por qué habrán quitado la serie de los Expedientes Secretos X?
#
# Iba a media temporada 10 😭😭😭😭
#
# Ahora que veré? 🤷
#
# Donde se hacen las reclamaciones? 😥    by: marleyleolim
# ------------------
# *RT @crunchyroll_la: Disfruta cada Domingo de #AttackOnTitan #ShingekiNoKyojin en Crunchyroll 🔥
#
# Sigue la serie aquí 👉 https://t.co/IHQVApH…    by: Miguel_MedinaC
# ------------------
# *RT @larixtinita: recordemos esta última escena de nuestra serie, ser mejor es la canción más especial 💜
# #9añosDeVioletta
# https://t.co/6htDT…    by: odette_mugo
# ------------------
# *Buen inicio de semana 😃😃😃. Los invitamos a ver el nuevo capítulo de nuestra serie "Derechos Humanos para ti". No te lo pierdas, da click aquí 🖌️👇
#
# https://t.co/n5igptzInd    by: PRODHEG
# ------------------
# *@WarnerChannelLA Los capítulos de estreno de sus series de Lunes a Jueves 9pm, repintanlos como lo hacían antes en lugar de la serie E.R.    by: RamonOswaldo_
# ------------------
# *RT @sallesino: Estudio de Animación: después de meses de trabajo duro, de ajustes y desvelos, por fin terminamos la intro de la nueva serie…    by: rorgejoa
# ------------------
# *RT @Ayynoquefeocaso: serie infravalorada q era una joya: https://t.co/dJFA3bzDP6    by: SofiaSandovalS
# ------------------
#
# ____________________________________________
# Música
# *@durbanoleon Dónde y qué necesito para reportar una finca que se utiliza como salón de fiestas en una zona habitacional donde es frecuente el ruido excesivo de música , entre otras cosas! Ayuda por favor !    by: Addieroga
# ------------------
# *@Bleyseryingyang @UnTalKenneth @InfoFreestyle2 De qué hablas? Le corrigió la rima de Reforma diciendo que se refería a Garibaldi y cuando se quejó de la temática le clavó la de música llanera para que viera que no era cuestión de la temática. 🙄🤦🏻‍♂️    by: Arturo_P_G
# ------------------
# *Me puse a llorar, tomar café, escuchar música clásica y leer poesía.
#
# (Nunca le digan a nadie mis hábitos tan emos)    by: brujamezcalera
# ------------------
# *A disfrutar la temporada de música en Vivo y nuestra parrilla al carbón con #hamburguesagourmet, #CortesPrime y nuestros #tragosdobles.  Servicio de #niñeras sábado y domingos  ☎️477 4296797 📍 Blvd Paseo del Juncal #211 a un costado de la EBC de Palmas zona norte https://t.co/j4JJ7TAeGo    by: burgues_leon
# ------------------
# *Festeja a papá como burgués, los esperamos con la parrilla encendida y los mejores #CortesPrime, #hamburguesagourmet #tragosdobles.
# 🎸Música en vivo jueves y sábados! ☎️477 4296797
# 📍Blvd Paseo del Juncal #211 a un costado de la EBC de Palmas zona norte https://t.co/6EEtStV1av    by: burgues_leon
# ------------------
# *#FriendsReunion  música en vivo
# Con amigos es mejor!!!!! ✌️✌️✌️ https://t.co/9PuJWGwHmU    by: burgues_leon
# ------------------
# *@YEFHACK Excelente!!!
# Te esperamos tenemos música en vivo a partir de las 8 pm jueves y viernes!!!!!!!!!!    by: burgues_leon
# ------------------
# *RT @luisoleg: La música que escuchaste hoy en #TRIÓNLive https://t.co/hXjG6WwgIt    by: DanyLira3
# ------------------
# *Disfruta de la música original y la poesía de grandes autores como Sor Juana Inés de la Cruz, Alaíde Foppa, Francisco de Terrazas y Nezahualcoyotl. https://t.co/7ZZkrikM2d    by: FenalMX
# ------------------
# *Hace ya 20 años, recuerdo que fui a una tienda de ropa con mis padres y no me gustaba la ropa de ahí, entonces ví un área donde tenían CD y unas orejeras para escuchar los CD, fue ahí donde los encontré, algo nuevo con muy buena música, el rock no estaba muerto... https://t.co/RrWXIa8zHL    by: Guspyfire2
# ------------------
# *Qué gran acierto de @los40mx meter un programa de música mezclada toda la semana :')
#
# #LOS40Sunset 🤩    by: Los40LeonFans
# ------------------
# *La música en vivo y yo nos extrañábamos demasiado    by: lucreciaamv
# ------------------
# *RT @Amelie_Earth: La noche. La música. El corazón. Y los latidos que cantan en silencio.    by: mariabonita_08
# ------------------
# *Nos vamos al Festival de las Luciérnagas ✨ con @elcaloncho en la música 🎶y Circo Elektrico con "Memoria de Gigantes". Estamos felices de ser parte de la reactivación de los eventos presenciales y volver a los distintos espacios en los que podemos vivir el arte y la cultura 💙. https://t.co/AMqJR6YPXf    by: PromotoraOniric
# ------------------
# *RT @MiguelChicoOfl: Vota MACH, letra y música de Euge Chico https://t.co/j2cLgQKje6    by: RanchoLaCumbre
# ------------------
# *Tiene alguien que hace su música con señas 👏🏾👏🏾👏🏾👏🏾 https://t.co/JJknP3PaDW    by: R_unborn
# ------------------
# *Cómo me gusta la música triste.    by: samenriquez_a
# ------------------
# *RT @guanajuato: Se acerca el #FestivalDeLaFresa en #Irapuato 😍❤️ Con Antojitos, postres, artesanías, música, danza, tours y más 🍓 Asiste de…    by: SaraSalinas1405
# ------------------
# *@viadirectaleon buen día en la calle la paz#101 la planta alta hay un gimnasio que tiene la música extremadamente alta ya se ha levantado diversas quejas visitan y se controlan por horas y vuelven, creen que puedan hacer algo serio al respecto las visitas no son suficientes    by: strada_alberto
# ------------------
# *Me acabo de dar cuenta que  @nadienosdijo usa música de #ElCastilloVagabundo mi cerebro está así🤯🤯🤯🤯🤯🤯🤯🤯 por apenas notarlo    by: tita_SalazarO
# ------------------
# *@BANDEMBORE @jorg3leiner Chalino Sánchez y Tigres del Norte llevaron la música mexicana a Estados Unidos.    by: Wicho_Urzua
# ------------------
#
# ____________________________________________
# Danza
# *RT @FIACmx: ¡La IV Muestra de Danza Contemporánea está lista para recibirte!💃
#
# Aquí la programación que presentará en formato presencial y…    by: algonald
# ------------------
# *RT @Reporte_Indigo: La danza también se ha visto afectada debido a la crisis sanitaria y la situación que enfrenta la Academia de la Danza…    by: david1alvarado
# ------------------
# *RT @CulturaUNAM: 🎶Compuesta en 1874 por Camille Saint-Saëns, "Danza macabra" está inspirada en un poema de Henri Cazalis, que recrea la ant…    by: LBerizu
# ------------------
# *RT @AstroAventura: Un dron consigue grabar la extraña «danza hipnótica» de una manada de renos    by: mauricioborja_
# ------------------
# *RT @guanajuato: Se acerca el #FestivalDeLaFresa en #Irapuato 😍❤️ Con Antojitos, postres, artesanías, música, danza, tours y más 🍓 Asiste de…    by: SaraSalinas1405
# ------------------
#
# ____________________________________________
# Postres
# *RT @guanajuato: Se acerca el #FestivalDeLaFresa en #Irapuato 😍❤️ Con Antojitos, postres, artesanías, música, danza, tours y más 🍓 Asiste de…    by: SaraSalinas1405
# ------------------
#
# ____________________________________________
